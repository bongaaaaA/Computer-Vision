# %%
from ultralytics import YOLO
import torch

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
dataset.location
# Out:
# 'c:\\Users\\ALSHELSS\\OneDrive\\Desktop\\system-Football-object-tracking\\training\\football-players-detection-1'

# %%
# !yolo task=detect mode=train model=yolov8n.pt data="C:/Users/ALSHELSS/OneDrive/Desktop/system-Football-object-tracking/training/Football-players-detection-1/data.yaml" epochs=100 imgsz=640
# Out:
# ^C

# %%
from ultralytics import YOLO
from roboflow import Roboflow

rf = Roboflow(api_key="7CElCpqOHdKGDktvLvLb")
project = rf.workspace("football-players-detection").project("football-players-detection")
version = project.version(1)
dataset = version.download("yolov5")

model = YOLO("yolov8n.pt")
model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=50,
    imgsz=640
)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# New https://pypi.org/project/ultralytics/8.3.253 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.252  Python-3.13.9 torch-2.9.1+cpu CPU (Intel Core i7-6820HQ 2.70GHz)
# ...
